# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome(r'E:\fliprobo technologies\chromedriver_win32\chromedriver.exe')
Url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(Url)

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]
try:
    ranks=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for rank in ranks:
        Rank.append(rank.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    Rank.append('not present')

try:
    Names=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for name in Names:
        Name.append(name.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    Rank.append('not present')
    
try:
    Artists=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
    for artist in Artists:
        Artist.append(artist.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    Rank.append('not present')  
    
try:
    Upload_dates=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
    for Upload_dte in Upload_dates:
        Upload_date.append(Upload_dte.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    Rank.append('not present')
    
try:
    Viewss=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
    for View in Viewss:
        Views.append(View.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    Rank.append('not present')

# %%
print(len(Rank),len(Name),len(Artist),len(Upload_date),len(Views))
# Out:
# 30 30 30 30 30

# %%
df=pd.DataFrame({'Rank':Rank,'Video':Name,'Views in billion':Views,'Artist':Artist,'Upload Date':Upload_date})
df=df.style.hide_index()
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bc0d">
#   <thead>
#     <tr>
#       <th id="T_5bc0d_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_5bc0d_level0_col1" class="col_heading level0 col1" >Video</th>
#       <th id="T_5bc0d_level0_col2" class="col_heading level0 col2" >Views in billion</th>
#       <th id="T_5bc0d_level0_col3" class="col_heading level0 col3" >Artist</th>
#       <th id="T_5bc0d_level0_col4" class="col_heading level0 col4" >Upload Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5bc0d_row0_col0" class="data row0 col0" >1.</td>
#       <td id="T_5bc0d_row0_col1" class="data row0 col1" >"Baby Shark Dance"[4]</td>
#       <td id="T_5bc0d_row0_col2" class="data row0 col2" >12.73</td>
#       <td id="T_5bc0d_row0_col3" class="data row0 col3" >Pinkfong Baby Shark - Kids' Songs & Stories</td>
#       <td id="T_5bc0d_row0_col4" class="data row0 col4" >June 17, 2016</td>
#     </tr>
#     <tr>
# ...

# %%
driver.close()

# %%
# 2nd question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chromedriver.exe')
Url = 'https://www.bcci.tv'
driver.get(Url)
time.sleep(2)
internation_fixture=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
internation_fixture.click()
time.sleep(2)

Matchtitle=[]
Series=[]
Place=[]
Date=[]
Time=[]
try:
    match=driver.find_element(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
    Matchtitle.append(match.text)
except NoSuchElementException as e:
    print('Exception raised:',e)

try:
    Serie=driver.find_element(By.XPATH,'//div[@class="match-card-middle__inner d-flex justify-content-between"]')
    Series.append(Serie.text.split('\n'))
except NoSuchElementException as e:
    print('Exception raised:',e)
    
try:
    places=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[3]/div')
    Place.append(places.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    
try:
    tie=driver.find_element(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
    Time.append(tie.text)
except NoSuchElementException as e:
    print('Exception raised:',e)
    
try:
    date=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/div/div[1]')
    Date.append(date.text)
except NoSuchElementException as e:
    print('Exception raised:',e)

# %%
print(len(Matchtitle),len(Series),len(Place),len(Date),len(Time))
# Out:
# 1 1 1 1 1

# %%
df=pd.DataFrame({'Title':Matchtitle,'Series':Series,'Date':Date,'Place':Place,'Time':Time})
df
# Out:
#                                     Title                  Series        Date  \
# 0  ICC WORLD TEST CHAMPIONSHIP FINAL 2023  [India, vs, Australia]  7 JUN 2023
#
#                              Place         Time
# 0  Final - Kennington Oval, London  3:30 PM IST

# %%
driver.close()

# %%
# 3rd question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chrome.exe')
Url = 'http://statisticstimes.com/'
driver.get(Url)
time.sleep(2)
click_on_economy=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
click_on_economy.click()
click_on_india=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
link=click_on_india.get_attribute('href')
driver.get(link)

# %%
click_on_gdpofindianstates=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
click_on_gdpofindianstates.click()
Rank=[]
State=[]
GSDP18_19=[]
GSDP19_20=[]
Share18_19=[]
GDP=[]
try:
    try:
        ranks=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[1]')
        for i in ranks:
            Rank.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)

    try:
        state=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[2]')
        for i in state:
             State.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)

    try:
        GSD18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[4]')
        for i in GSD18_19:
            GSDP18_19.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)

    try:
        GSD19_20=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[3]')
        for i in GSD19_20:
            GSDP19_20.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)

    try:
        share18_19=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[5]')
        for i in share18_19:
            Share18_19.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)

    try:
        gdp=driver.find_elements(By.XPATH,'//table[@id="table_id"]/tbody/tr/td[6]')
        for i in gdp:
            GDP.append(i.text)
    except NoSuchElementException as e:
        print('exception raised:',e)   

except:
    print('code is wrong unable to scrap data')

# %%
print(len(Rank),len(State),len(GSDP18_19),len(GSDP19_20),len(Share18_19),len(GDP))
# Out:
# 33 33 33 33 33 33

# %%
df=pd.DataFrame({'Rank':Rank,'State':State,'GSDP(18-19)':GSDP18_19,'GSDP(19-20)':GSDP19_20,'Share(18-19)':Share18_19,'GDP':GDP})
df=df.style.hide_index()
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_e126c">
#   <thead>
#     <tr>
#       <th id="T_e126c_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_e126c_level0_col1" class="col_heading level0 col1" >State</th>
#       <th id="T_e126c_level0_col2" class="col_heading level0 col2" >GSDP(18-19)</th>
#       <th id="T_e126c_level0_col3" class="col_heading level0 col3" >GSDP(19-20)</th>
#       <th id="T_e126c_level0_col4" class="col_heading level0 col4" >Share(18-19)</th>
#       <th id="T_e126c_level0_col5" class="col_heading level0 col5" >GDP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e126c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e126c_row0_col1" class="data row0 col1" >Maharashtra</td>
#       <td id="T_e126c_row0_col2" class="data row0 col2" >2,632,792</td>
#       <td id="T_e126c_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_e126c_row0_col4" class="data row0 col4" >13.94%</td>
# ...

# %%
driver.close()

# %%
# 4th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chrome.exe')
Url = 'https://github.com/'
driver.get(Url)
time.sleep(2)
click_on_opensource=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
click_on_opensource.click()
click_on_trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
click_on_trending.click()

# %%
url=[]
Repository=[]
description=[]
Contributors_count=[]
Language_used=[]

links=driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]/a')
for i in links:
    url.append(i.get_attribute('href'))
for i in url:
    driver.get(i)
    
    try:
        repository=driver.find_element(By.XPATH,'//div[@class=" d-flex flex-wrap flex-items-center wb-break-word f3 text-normal"]') 
        Repository.append(repository.text)
    except NoSuchElementException as e:
        print('exception raised:',e)
        
    try:
        descrip=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/main/turbo-frame/div/div/div/div[2]/div[2]/div/div[1]/div/p') 
        description.append(descrip.text)
    except NoSuchElementException as e:
        print('exception raised:',e)
        
    try:
        Contributors=driver.find_element(By.XPATH,'//div[@class="BorderGrid-row"][4]/div/h2/a/span') 
        Contributors_count.append(Contributors.text)
    except NoSuchElementException as e:
        print('exception raised:',e)
        try:
            Contributors=driver.find_element(By.XPATH,'//div[@class="BorderGrid BorderGrid--spacious"]/div[3]/div/h2/a/span') 
            Contributors_count.append(Contributors.text)
        except:
            Contributors_count.append('-')
    try:
        Language=driver.find_element(By.XPATH,'//div[@class="BorderGrid-row"][5]/div/ul') 
        Language_used.append(Language.text)
    except NoSuchElementException as e:
        print('exception raised:',e)
        try:
            Language=driver.find_element(By.XPATH,'//div[@class="BorderGrid BorderGrid--spacious"]/div[4]/div/ul') 
            Language_used.append(Language.text)
        except:
            try:
                Language=driver.find_element(By.XPATH,'//div[@class="BorderGrid BorderGrid--spacious"]/div[3]/div/ul') 
                Language_used.append(Language.text)
            except:
                Language_used.append('-')
# Out:
# exception raised: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class="BorderGrid-row"][4]/div/h2/a/span"}
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x010F8893+48451]
# 	(No symbol) [0x0108B8A1]
# 	(No symbol) [0x00F95058]
# 	(No symbol) [0x00FC0467]
# 	(No symbol) [0x00FC069B]
# 	(No symbol) [0x00FEDD92]
# 	(No symbol) [0x00FDA304]
# 	(No symbol) [0x00FEC482]
# 	(No symbol) [0x00FDA0B6]
# 	(No symbol) [0x00FB7E08]
# 	(No symbol) [0x00FB8F2D]
# 	GetHandleVerifier [0x01358E3A+2540266]
# 	GetHandleVerifier [0x01398959+2801161]
# 	GetHandleVerifier [0x0139295C+2776588]
# 	GetHandleVerifier [0x01182280+612144]
# 	(No symbol) [0x01094F6C]
# 	(No symbol) [0x010911D8]
# 	(No symbol) [0x010912BB]
# 	(No symbol) [0x01084857]
# 	BaseThreadInitThunk [0x76697D59+25]
# 	RtlInitializeExceptionChain [0x77DFB74B+107]
# 	RtlClearBits [0x77DFB6CF+191]
#
# ...

# %%
print(len(Repository),len(description),len(Contributors_count),len(Language_used))
# Out:
# 25 25 25 25

# %%
df=pd.DataFrame({'Repository Name':Repository,'Repository description':description,'Contributors_count':Contributors_count,'Language_used':Language_used})
df
# Out:
#                                  Repository Name  \
# 0           facebookresearch\n/\nfairseq\nPublic
# 1                  JiauZhang\n/\nDragGAN\nPublic
# 2          google\n/\ncomprehensive-rust\nPublic
# 3               NaiboWang\n/\nEasySpider\nPublic
# 4              w-okada\n/\nvoice-changer\nPublic
# 5                Zeqiang-Lai\n/\nDragGAN\nPublic
# 6               pengxiao-song\n/\nLaWGPT\nPublic
# 7          kyegomez\n/\ntree-of-thoughts\nPublic
# 8   Blazity\n/\nnext-enterprise\nPublic template
# 9                    kamiyaa\n/\njoshuto\nPublic
# 10            iryna-kondr\n/\nscikit-llm\nPublic
# 11               0nutation\n/\nSpeechGPT\nPublic
# 12                     UFund-Me\n/\nQbot\nPublic
# 13                     casbin\n/\ncasbin\nPublic
# 14    adams549659584\n/\ngo-proxy-bingai\nPublic
# 15                   BlinkDL\n/\nRWKV-LM\nPublic
# 16                 jaywalnut310\n/\nvits\nPublic
# 17                     csunny\n/\nDB-GPT\nPublic
# ...

# %%
driver.close()

# %%
# 5th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,ElementNotInteractableException

# %%
chrome_options=Options()
chrome_options.add_argument('--incognito')
driver=webdriver.Chrome(options=chrome_options)
Url = 'https:/www.billboard.com/'
driver.get(Url)

# %%
try:
    click_on_charts=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/a')
    click_on_charts.click()
except ElementNotInteractableException as e:
    print('exception raised:',e)
    click_on_charts=driver.find_element(By.XPATH,'/html/body/div[3]/footer/div[4]/div/div/div[2]/div[3]/div/nav[3]/ul/li[1]/a')
    driver.get(click_on_charts.get_attribute('href'))
# Out:
# exception raised: Message: element not interactable
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00228893+48451]
# 	(No symbol) [0x001BB8A1]
# 	(No symbol) [0x000C4F20]
# 	(No symbol) [0x000F13A6]
# 	(No symbol) [0x000E9AAC]
# 	(No symbol) [0x0010A2BC]
# 	(No symbol) [0x000E9586]
# 	(No symbol) [0x0010A614]
# 	(No symbol) [0x0011C482]
# 	(No symbol) [0x0010A0B6]
# 	(No symbol) [0x000E7E08]
# 	(No symbol) [0x000E8F2D]
# 	GetHandleVerifier [0x00488E3A+2540266]
# 	GetHandleVerifier [0x004C8959+2801161]
# 	GetHandleVerifier [0x004C295C+2776588]
# 	GetHandleVerifier [0x002B2280+612144]
# 	(No symbol) [0x001C4F6C]
# 	(No symbol) [0x001C11D8]
# 	(No symbol) [0x001C12BB]
# 	(No symbol) [0x001B4857]
# 	BaseThreadInitThunk [0x76697D59+25]
# 	RtlInitializeExceptionChain [0x77DFB74B+107]
# 	RtlClearBits [0x77DFB6CF+191]
# 	(No symbol) [0x00000000]

# %%
click_on_hot100=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[3]/div/div/div[2]/div/div[1]/a/span/span')
click_on_hot100.click()

# %%
Songname=[]
Artistname=[]
Lastweekrank=[]
Peakrank=[]
Weeksonboard=[]
try:
    song=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3')
    for i in song:
        Songname.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Artist=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[1]/span')
    for i in Artist:
        Artistname.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Lastweekra=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[4]')
    for i in Lastweekra:
        Lastweekrank.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Peakra=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[5]')
    for i in Peakra:
        Peakrank.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Weekson=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[6]')
    for i in Weekson:
        Weeksonboard.append(i.text)
except NoSuchElementException:
    print('exception raised')

# %%
print(len(Songname),len(Artistname),len(Lastweekrank),len(Peakrank),len(Weeksonboard))
# Out:
# 100 100 100 100 100

# %%
df=pd.DataFrame({'Song name':Songname,'Artist name':Artistname,'Last week rank':Lastweekrank,'Peak rank':Peakrank,'Weeks on board':Weeksonboard})
df
# Out:
#           Song name                                   Artist name  \
# 0        Last Night                                 Morgan Wallen
# 1       All My Life                    Lil Durk Featuring J. Cole
# 2           Flowers                                   Miley Cyrus
# 3         Kill Bill                                           SZA
# 4   Ella Baila Sola                   Eslabon Armado X Peso Pluma
# ..              ...                                           ...
# 95          Forever                    Lil Baby Featuring Fridayy
# 96  Private Landing  Don Toliver Featuring Justin Bieber & Future
# 97          I Heard                    YoungBoy Never Broke Again
# 98          Sunrise                                 Morgan Wallen
# 99            Happy                                            NF
#
#    Last week rank Peak rank Weeks on board
# 0               1         1             16
# 1               -         2              1
# ...

# %%
driver.close()

# %%
# 6th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chromedriver.exe')
Url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(Url)

# %%
Bookname=[]
Authorname=[]
Volumessold=[]
Publisher=[]
Genre=[]

book=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in book:
    Bookname.append(i.text)
Author=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in Author:
    Authorname.append(i.text)
Volumes=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in Volumes:
    Volumessold.append(i.text)
Publish=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in Publish:
    Publisher.append(i.text)
Gen=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in Gen:
    Genre.append(i.text)

# %%
print(len(Bookname),len(Authorname),len(Volumessold),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
df=pd.DataFrame({'Novel':Bookname,'Author':Authorname,'Volumes sold':Volumessold,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#                                                 Novel            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %%
# 7th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chromedriver.exe')
Url = 'https://www.imdb.com/list/ls095964455/'
driver.get(Url)

# %%
Name=[]
Yearspan=[]
Genre=[]
Runtime=[]
Ratings=[]
Votes=[]

try:
    name=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Year=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
    for i in Year:
        Yearspan.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Genr=driver.find_elements(By.CLASS_NAME,'genre')
    for i in Genr:
        Genre.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Run=driver.find_elements(By.CLASS_NAME,'runtime')
    for i in Run:
        Runtime.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Rating=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[2]')
    for i in Rating:
        Ratings.append(i.text)
except NoSuchElementException:
    print('exception raised')
    
try:
    Vote=driver.find_elements(By.XPATH,'//span[@name="nv"]')
    for i in Vote:
        Votes.append(i.text)
except NoSuchElementException:
    print('exception raised')

# %%
print(len(Name),len(Yearspan),len(Genre),len(Runtime),len(Ratings),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
df=pd.DataFrame({'TV Shows':Name,'Year span':Yearspan,'Genre':Genre,'Run time':Runtime,'Ratings':Ratings,'Votes':Votes})
df
# Out:
#                           TV Shows    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2022)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,162,243
# ...

# %%
driver.close()

# %%
# 8th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chromedriver.exe')
Url = 'https://archive.ics.uci.edu/'
driver.get(Url)

# %%
click_on_viewall_datasets=driver.find_element(By.XPATH,'//span[@class="whitetext"][2]/a')
click_on_viewall_datasets.click()

# %%
Datasetname=[]
Datatype=[]
Task=[]
Attributetype=[]
Noofinstances=[]
Noofattribute=[]
Year=[]
try:
    Dataset=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[1]')
    for i in Dataset:
        Datasetname.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    datatype=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[2]')
    for i in datatype:
        Datatype.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    task=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[3]')
    for i in task:
        Task.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    attributetype=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[4]')
    for i in attributetype:
        Attributetype.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    instances=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[5]')
    for i in instances:
        Noofinstances.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    atribute=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[6]')
    for i in atribute:
        Noofattribute.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

try:
    year=driver.find_elements(By.XPATH,'//table[@border="1"]/tbody/tr/td[7]')
    for i in year:
        Year.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)

# %%
print(len(Datasetname),len(Datatype),len(Task),len(Attributetype),len(Noofinstances),len(Noofattribute),len(Year))
# Out:
# 623 623 623 623 623 623 623

# %%
df=pd.DataFrame({'Data set name':Datasetname[1:],'Data type':Datatype[1:],'Task':Task[1:],'Attribute type':Attributetype[1:],'No of instances':Noofinstances[1:],'No of attribute':Noofattribute[1:],'Year':Year[1:]})
df
# Out:
#                                          Data set name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617    Influenza outbreak event prediction via Twit...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621    Image Recognition Task Execution Times in Mo...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
driver.close()

# %%
# 9th question answer

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException

# %%
driver=webdriver.Chrome('chromedriver.exe')
Url = 'https://www.naukri.com/hr-recruiters-consultants'
driver.get(Url)

# %%
search=driver.find_element(By.XPATH,'//input[@class="sugInp"]')
search.send_keys('Data science')
click_on_search=driver.find_element(By.XPATH,'//button[@id="qsbFormBtn"]')
click_on_search.click()

# %%
Name=[]
Designation=[]
Company=[]
Skillstheyhirefor=[]
Location=[]
try:
    name=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for i in name:
        Name.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)
    
try:
    designation=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for i in designation:
        Designation.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)
    
try:
    company=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[2]')
    for i in company:
        Company.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)
    
try:
    Skills=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in Skills:
        Skillstheyhirefor.append(i.text)
except NoSuchElementException as e:
    print('exception raised:',e)
    
try:
    location=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[2]')
    for i in location:
        Location.append(i.text)
except NoSuchElementException :
    print('exception raised:',e)    
    Location.append('-')

# %%
print(len(Name),len(Designation),len(Company),len(Skillstheyhirefor),len(Location))
# Out:
# 50 50 50 50 49

# %%
Location.insert(30,'-')
print(len(Name),len(Designation),len(Company),len(Skillstheyhirefor),len(Location))
# Out:
# 50 50 50 50 50

# %%
df=pd.DataFrame({'Name':Name,'Designation':Designation,'Company':Company,'Skills they hire for':Skillstheyhirefor,'Location':Location})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()
